# %% [markdown]
# ### References
#
# https://www.tensorflow.org/tutorials/load_data/images
#
# https://www.tensorflow.org/api_docs/python/tf/data/Dataset
#
# https://www.youtube.com/watch?v=yH1cF7GnoIo
#
# https://www.datacamp.com/community/tutorials/tensorflow-tutorial

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,TensorBoard, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization, LeakyReLU 
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

import os
import numpy as np

# plotting
import matplotlib.pyplot as plt
import pathlib
from PIL import Image
import IPython.display as display

# to display confusion matrix
import seaborn as sn
import pandas as pd

# %% [markdown]
# ### Aux functions

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return parts[-2] == classNames

def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_png(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [32,32])

def get_bytes_and_label(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

def show_data(s1,l1, s2,l2, labels, min):
    fig, ax = plt.subplots()
    X = np.arange(len(s1))

    models = labels
    plt.bar(X, s1, width = 0.4, color = 'b', label=l1)
    plt.bar(X + 0.4, s2, color = 'r', width = 0.4, label = l2)
    plt.xticks(X + 0.4 / 2, models)
    plt.ylim(top = 100, bottom = min)
    plt.legend(loc='upper left')
    plt.show()

def show_batch(image_batch, label_batch):
  columns = 6
  rows = BATCH_SIZE / columns + 1  
  plt.figure(figsize=(10, 2 * rows))
  for n in range(BATCH_SIZE):
      ax = plt.subplot(int(rows), columns, n+1)
      plt.imshow((image_batch[n]))
      plt.title(classNames[label_batch[n]==1][0])
      plt.axis('off')


def show_history(history):
    print(history.history.keys())

    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='lower right')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper right')
    plt.show()    


def show_accuracies(labels, test, val): 

    fig, ax = plt.subplots()
    X = np.arange(len(test))

    plt.bar(X, test, width = 0.4, color = 'b', label='test')
    plt.bar(X + 0.4, val, color = 'r', width = 0.4, label = "val")
    plt.xticks(X + 0.4 / 2, labels)
    plt.ylim(top = 1.0, bottom = 0.97)
    plt.legend(loc='upper left')
    plt.show()    



def show_misclassified(predictions, ground_truth, images, num_rows = 5, num_cols=3):
    
    # Plot the first X test images with wrong predictions.
    num_images = num_rows*num_cols
    print(num_images)
    plt.figure(figsize=(2*2*num_cols, 2*num_rows))
    i = 0
    k = 0
    while k < len(images) and i < num_images:
        predicted_label = np.argmax(predictions[k])
        gt = np.where(ground_truth[k])[0][0]
        if predicted_label != gt:
            plt.subplot(num_rows, 2*num_cols, 2*i+1)
            plot_image(k, predictions[k], gt, images)
            plt.subplot(num_rows, 2*num_cols, 2*i+2)
            plot_value_array(k, predictions[k], ground_truth)
            i += 1
        k += 1
    plt.tight_layout()
    plt.show()


def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label, img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.binary)
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
      color = 'blue'
    else:
      color = 'red'
    
    plt.xlabel("{} {:2.0f}% ({})".format(classNames[predicted_label],
                                100*np.max(predictions_array),
                                classNames[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(8))
    plt.yticks([])
    thisplot = plt.bar(range(8), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[np.where(true_label)[0][0]].set_color('blue')   



def show_confusion_matrix(mat, classes):

    df_cm = pd.DataFrame(mat, range(classes), range(classes))
    plt.figure(figsize=(15,10))
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d') # font size

    plt.show()

# %%
def prepare_callbacks(file_path):

    checkpointer = ModelCheckpoint(filepath= file_path, 
                               monitor = 'val_accuracy',
                               verbose=1, 
                               save_weights_only=True,
                               save_best_only=True)


    earlyStopper = EarlyStopping(monitor='val_loss', min_delta = 0.0001, patience = 15, verbose = 1)

    reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.000000001, verbose = 1)

    return [checkpointer, earlyStopper, reduceLR]

# %% [markdown]
# ### Batch size
#
# Batch size is an important parameter when training a network. It can influence speed and generalization, not necessarily in the same direction. There is no golden rule for the batch size but 32 is a commom number to start with.
#
# In here we go to 64 to achieve faster training epochs (rather than 32)
#
# See: https://machinelearningmastery.com/how-to-control-the-speed-and-stability-of-training-neural-networks-with-gradient-descent-batch-size/

# %%
BATCH_SIZE = 64
IMAGE_SIZE = 32

# %% [markdown]
# ### Prepare to load images

# %%
data_dir = pathlib.Path('d:/temp/DL04/gtsrb/train_images/')
  
classNames = np.array(os.listdir(data_dir))
classNames
# Out:
# array(['00000', '00001', '00002', '00003', '00004', '00005', '00006',
#        '00007'], dtype='<U5')

# %% [markdown]
# ### Loading images takes place in here

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

listset = tf.data.Dataset.list_files("d:/temp/DL04/gtsrb/train_images/*/*.png")
dataset = listset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)

# %% [markdown]
# ### Information about image shape and size of training set

# %%
t = next(iter(dataset))
print(t[0].shape, t[1].shape)

# note: this only works if dataset is not repeating
dataset_length = tf.data.experimental.cardinality(dataset).numpy()
print("Total images in dataset: ", dataset_length)
# Out:
# (32, 32, 3) (8,)
# Total images in dataset:  10200

# %% [markdown]
# # Version I - training with dataset only

# %% [markdown]
# ### Preparing training, validation and test datasets

# %%
dataSolo = dataset
dataSolo = dataSolo.cache()
dataSolo = dataSolo.shuffle(buffer_size = dataset_length)
dataSolo = dataSolo.prefetch(buffer_size=10200)
dataSolo = dataSolo.batch(batch_size=BATCH_SIZE)
#dataSolo = dataSolo.repeat()

# %%
val_listset = tf.data.Dataset.list_files("d:/temp/DL04/gtsrb/val_images/*/*.png")
val_dataset_length = val_listset.cardinality().numpy()
print("Total images in validatation dataset: ", val_dataset_length)

valset = val_listset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)
valset = valset.cache()
valset = valset.shuffle(buffer_size = 2580)
valset = valset.batch(batch_size = 2580)
valset = valset.prefetch(buffer_size = AUTOTUNE)
# Out:
# Total images in validatation dataset:  2580

# %%
test_listset = tf.data.Dataset.list_files("d:/temp/DL04/gtsrb/test_images_per_folder/*/*.png")
test_dataset_length = test_listset.cardinality().numpy()
print("Total images in validatation dataset: ", test_dataset_length)

testset = test_listset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)
testset = testset.batch(batch_size = BATCH_SIZE)
# Out:
# Total images in validatation dataset:  4170

# %% [markdown]
# ### Show a batch of training images

# %%
        
        
image_batch, label_batch = next(iter(dataSolo))        
show_batch(image_batch, label_batch.numpy())

# %% [markdown]
# ### Build a CNN network

# %%
def model_VI(classCount, imgSize, channels):

    model = Sequential()
    
    model.add(Conv2D(128, (5, 5),
                     input_shape=(imgSize, imgSize, channels)))         
    model.add(LeakyReLU(alpha=0.01))  
    model.add(BatchNormalization())
    model.add(Dropout(0.5)) 

    model.add(Conv2D(196, (5, 5) )) 
    model.add(LeakyReLU(alpha=0.01))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.5)) 

    model.add(Conv2D(256, (5, 5) ) )   
    model.add(LeakyReLU(alpha=0.01))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.5)) 
    
    model.add(Flatten())
    model.add(LeakyReLU(alpha=0.0)) 
    model.add(Dense(384))
    model.add(LeakyReLU(alpha=0.0))             
    model.add(Dropout(0.5)) 
    
    model.add(Dense(classCount, activation='softmax'))

    
    opt = Adam(lr=0.0001)
    model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=[ 'accuracy'])
    return model

# %%
modelV1 = model_VI(8, 32, 3)

print(modelV1.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       9728
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 28, 28, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 196)       627396
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 24, 24, 196)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 196)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 196)       784
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 12, 12, 196)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         1254656
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 384)               1573248
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 384)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 384)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 3080
# =================================================================
# Total params: 3,470,428
# Trainable params: 3,469,268
# Non-trainable params: 1,160
# _________________________________________________________________
# None

# %% [markdown]
# ### Train the network

# %%
file_pathV1 = 'd:/temp/DL04/DA_modelV1/cp.ckpt'

# %%
callbacksV1 = prepare_callbacks(file_pathV1)

historyV1 = modelV1.fit(dataSolo,
          epochs=50, 
          validation_data = valset, 
          callbacks = callbacksV1)
# Out:
# Epoch 1/50
# 160/160 [==============================] - 3s 18ms/step - loss: 2.4822 - accuracy: 0.2192 - val_loss: 2.0109 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 2/50
# 160/160 [==============================] - 2s 13ms/step - loss: 1.7867 - accuracy: 0.3110 - val_loss: 1.9829 - val_accuracy: 0.1903
#
# Epoch 00002: val_accuracy improved from 0.17442 to 0.19031, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 3/50
# 160/160 [==============================] - 2s 12ms/step - loss: 1.4880 - accuracy: 0.4423 - val_loss: 1.5309 - val_accuracy: 0.3876
#
# Epoch 00003: val_accuracy improved from 0.19031 to 0.38760, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 4/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.9169 - accuracy: 0.6666 - val_loss: 0.6631 - val_accuracy: 0.7795
#
# Epoch 00004: val_accuracy improved from 0.38760 to 0.77946, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 5/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.4989 - accuracy: 0.8360 - val_loss: 0.2914 - val_accuracy: 0.9217
#
# Epoch 00005: val_accuracy improved from 0.77946 to 0.92171, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 6/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.3166 - accuracy: 0.8972 - val_loss: 0.1865 - val_accuracy: 0.9434
#
# Epoch 00006: val_accuracy improved from 0.92171 to 0.94341, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 7/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.2233 - accuracy: 0.9246 - val_loss: 0.1304 - val_accuracy: 0.9624
#
# Epoch 00007: val_accuracy improved from 0.94341 to 0.96240, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 8/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.1654 - accuracy: 0.9481 - val_loss: 0.1183 - val_accuracy: 0.9605
#
# Epoch 00008: val_accuracy did not improve from 0.96240
# Epoch 9/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.1300 - accuracy: 0.9604 - val_loss: 0.0873 - val_accuracy: 0.9760
#
# Epoch 00009: val_accuracy improved from 0.96240 to 0.97597, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 10/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.1014 - accuracy: 0.9684 - val_loss: 0.1005 - val_accuracy: 0.9632
#
# Epoch 00010: val_accuracy did not improve from 0.97597
# Epoch 11/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0823 - accuracy: 0.9729 - val_loss: 0.0737 - val_accuracy: 0.9756
#
# Epoch 00011: val_accuracy did not improve from 0.97597
# Epoch 12/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0719 - accuracy: 0.9767 - val_loss: 0.0687 - val_accuracy: 0.9760
#
# Epoch 00012: val_accuracy did not improve from 0.97597
# Epoch 13/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0543 - accuracy: 0.9812 - val_loss: 0.0776 - val_accuracy: 0.9725
#
# Epoch 00013: val_accuracy did not improve from 0.97597
# Epoch 14/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0504 - accuracy: 0.9841 - val_loss: 0.0773 - val_accuracy: 0.9725
#
# Epoch 00014: val_accuracy did not improve from 0.97597
# Epoch 15/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0464 - accuracy: 0.9836 - val_loss: 0.0655 - val_accuracy: 0.9791
#
# Epoch 00015: val_accuracy improved from 0.97597 to 0.97907, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 16/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0508 - accuracy: 0.9829 - val_loss: 0.0592 - val_accuracy: 0.9833
#
# Epoch 00016: val_accuracy improved from 0.97907 to 0.98333, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 17/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0359 - accuracy: 0.9871 - val_loss: 0.0655 - val_accuracy: 0.9748
#
# Epoch 00017: val_accuracy did not improve from 0.98333
# Epoch 18/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0326 - accuracy: 0.9888 - val_loss: 0.0591 - val_accuracy: 0.9787
#
# Epoch 00018: val_accuracy did not improve from 0.98333
# Epoch 19/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0303 - accuracy: 0.9897 - val_loss: 0.0705 - val_accuracy: 0.9756
#
# Epoch 00019: val_accuracy did not improve from 0.98333
# Epoch 20/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0264 - accuracy: 0.9921 - val_loss: 0.0620 - val_accuracy: 0.9791
#
# Epoch 00020: val_accuracy did not improve from 0.98333
# Epoch 21/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0237 - accuracy: 0.9922 - val_loss: 0.0838 - val_accuracy: 0.9709
#
# Epoch 00021: val_accuracy did not improve from 0.98333
# Epoch 22/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0245 - accuracy: 0.9922 - val_loss: 0.0709 - val_accuracy: 0.9787
#
# Epoch 00022: val_accuracy did not improve from 0.98333
# Epoch 23/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0204 - accuracy: 0.9938 - val_loss: 0.0514 - val_accuracy: 0.9833
#
# Epoch 00023: val_accuracy did not improve from 0.98333
# Epoch 24/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0207 - accuracy: 0.9947 - val_loss: 0.0519 - val_accuracy: 0.9853
#
# Epoch 00024: val_accuracy improved from 0.98333 to 0.98527, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 25/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0214 - accuracy: 0.9925 - val_loss: 0.0647 - val_accuracy: 0.9771
#
# Epoch 00025: val_accuracy did not improve from 0.98527
# Epoch 26/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 0.0625 - val_accuracy: 0.9795
#
# Epoch 00026: val_accuracy did not improve from 0.98527
# Epoch 27/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.0737 - val_accuracy: 0.9740
#
# Epoch 00027: val_accuracy did not improve from 0.98527
# Epoch 28/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0169 - accuracy: 0.9931 - val_loss: 0.0722 - val_accuracy: 0.9756
#
# Epoch 00028: val_accuracy did not improve from 0.98527
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 29/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0465 - val_accuracy: 0.9853
#
# Epoch 00029: val_accuracy did not improve from 0.98527
# Epoch 30/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.0387 - val_accuracy: 0.9876
#
# Epoch 00030: val_accuracy improved from 0.98527 to 0.98760, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 31/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0087 - accuracy: 0.9976 - val_loss: 0.0335 - val_accuracy: 0.9895
#
# Epoch 00031: val_accuracy improved from 0.98760 to 0.98953, saving model to d:/temp/DL04/DA_modelV1\cp.ckpt
# Epoch 32/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0072 - accuracy: 0.9984 - val_loss: 0.0585 - val_accuracy: 0.9802
#
# Epoch 00032: val_accuracy did not improve from 0.98953
# Epoch 33/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.0410 - val_accuracy: 0.9864
#
# Epoch 00033: val_accuracy did not improve from 0.98953
# Epoch 34/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.0528 - val_accuracy: 0.9837
#
# Epoch 00034: val_accuracy did not improve from 0.98953
# Epoch 35/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0092 - accuracy: 0.9979 - val_loss: 0.0486 - val_accuracy: 0.9857
#
# Epoch 00035: val_accuracy did not improve from 0.98953
# Epoch 36/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0473 - val_accuracy: 0.9860
#
# Epoch 00036: val_accuracy did not improve from 0.98953
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 37/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 0.0439 - val_accuracy: 0.9864
#
# Epoch 00037: val_accuracy did not improve from 0.98953
# Epoch 38/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.0403 - val_accuracy: 0.9872
#
# Epoch 00038: val_accuracy did not improve from 0.98953
# Epoch 39/50
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0056 - accuracy: 0.9973 - val_loss: 0.0411 - val_accuracy: 0.9876
#
# Epoch 00039: val_accuracy did not improve from 0.98953
# Epoch 40/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0379 - val_accuracy: 0.9876
#
# Epoch 00040: val_accuracy did not improve from 0.98953
# Epoch 41/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0441 - val_accuracy: 0.9853
#
# Epoch 00041: val_accuracy did not improve from 0.98953
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 42/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0388 - val_accuracy: 0.9876
#
# Epoch 00042: val_accuracy did not improve from 0.98953
# Epoch 43/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0314 - val_accuracy: 0.9891
#
# Epoch 00043: val_accuracy did not improve from 0.98953
# Epoch 44/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.0402 - val_accuracy: 0.9872
#
# Epoch 00044: val_accuracy did not improve from 0.98953
# Epoch 45/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0391 - val_accuracy: 0.9872
#
# Epoch 00045: val_accuracy did not improve from 0.98953
# Epoch 46/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0333 - val_accuracy: 0.9888
#
# Epoch 00046: val_accuracy did not improve from 0.98953
# Epoch 47/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.0366 - val_accuracy: 0.9895
#
# Epoch 00047: val_accuracy did not improve from 0.98953
# Epoch 48/50
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0413 - val_accuracy: 0.9876
#
# Epoch 00048: val_accuracy did not improve from 0.98953
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 49/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.0388 - val_accuracy: 0.9884
#
# Epoch 00049: val_accuracy did not improve from 0.98953
# Epoch 50/50
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0353 - val_accuracy: 0.9891
#
# Epoch 00050: val_accuracy did not improve from 0.98953

# %% [markdown]
# ### Plot the training history

# %%
show_history(historyV1)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# ### Evaluate Model

# %%
modelV1.load_weights(file_pathV1)

evalV1 = modelV1.evaluate(testset, verbose=2)
valV1 = modelV1.evaluate(valset, verbose=2)
# Out:
# 66/66 - 1s - loss: 0.0660 - accuracy: 0.9808
# 1/1 - 0s - loss: 0.0335 - accuracy: 0.9895

# %% [markdown]
# # Version II - dynamic data augmentation

# %% [markdown]
# ### Function to transform image

# %%
#https://www.tensorflow.org/api_docs/python/tf/image
#https://www.tensorflow.org/addons/api_docs/python/tfa/image

#pip install tensorflow-addons
import tensorflow_addons as tfa


def process_image(image, label):
    
    # random rotate 5 degrees
    r = tf.random.uniform(shape=(), minval=-0.175, maxval=0.175, dtype=tf.dtypes.float32)
    image = tfa.image.rotate(image, r)

    # translate image up to 10%
    rx = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32) 
    ry = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32) 
    image = tfa.image.translate(image, [rx, ry])
   
    # change hue, saturation and value
    image = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.2, 0.4, 1.1, 0.4, 1.1),0,1)

    return image, label

# %%
dataV2 = dataset
dataV2 = dataV2.cache()
dataV2 = dataV2.shuffle(buffer_size = dataset_length)
dataV2 = dataV2.map(process_image)
dataV2 = dataV2.prefetch(buffer_size=10200)
dataV2 = dataV2.batch(batch_size=BATCH_SIZE)
#dataV2 = dataV2.repeat()

# %%
modelV2 = model_VI(8, 32, 3)

file_pathV2 = 'd:/temp/DL04/DA_modelV2/cp.ckpt'

callbacksV2 = prepare_callbacks(file_pathV2)

# historyV2 = modelV2.fit(dataV2, steps_per_epoch = 10200/BATCH_SIZE,
#           epochs=50, 
#           validation_data = valset, 
#           callbacks = callbacksV2)

historyV2 = modelV2.fit(dataV2,
          epochs=50, 
          validation_data = valset, 
          callbacks = callbacksV2)
# Out:
# Epoch 1/50
# 160/160 [==============================] - 5s 16ms/step - loss: 2.5155 - accuracy: 0.2010 - val_loss: 2.0310 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 2/50
# 160/160 [==============================] - 3s 16ms/step - loss: 1.9131 - accuracy: 0.2561 - val_loss: 2.0604 - val_accuracy: 0.1744
#
# Epoch 00002: val_accuracy did not improve from 0.17442
# Epoch 3/50
# 160/160 [==============================] - 3s 16ms/step - loss: 1.8518 - accuracy: 0.2763 - val_loss: 1.9833 - val_accuracy: 0.1814
#
# Epoch 00003: val_accuracy improved from 0.17442 to 0.18140, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 4/50
# 160/160 [==============================] - 3s 16ms/step - loss: 1.8121 - accuracy: 0.2900 - val_loss: 1.8755 - val_accuracy: 0.2450
#
# Epoch 00004: val_accuracy improved from 0.18140 to 0.24496, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 5/50
# 160/160 [==============================] - 3s 16ms/step - loss: 1.7418 - accuracy: 0.3221 - val_loss: 1.7420 - val_accuracy: 0.3174
#
# Epoch 00005: val_accuracy improved from 0.24496 to 0.31744, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 6/50
# 160/160 [==============================] - 3s 16ms/step - loss: 1.6799 - accuracy: 0.3465 - val_loss: 1.6766 - val_accuracy: 0.3539
#
# Epoch 00006: val_accuracy improved from 0.31744 to 0.35388, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 7/50
# 160/160 [==============================] - 3s 16ms/step - loss: 1.5466 - accuracy: 0.4004 - val_loss: 1.3728 - val_accuracy: 0.4616
#
# Epoch 00007: val_accuracy improved from 0.35388 to 0.46163, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 8/50
# 160/160 [==============================] - 3s 16ms/step - loss: 1.3598 - accuracy: 0.4820 - val_loss: 0.9527 - val_accuracy: 0.6578
#
# Epoch 00008: val_accuracy improved from 0.46163 to 0.65775, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 9/50
# 160/160 [==============================] - 3s 16ms/step - loss: 1.0924 - accuracy: 0.6005 - val_loss: 0.5693 - val_accuracy: 0.8039
#
# Epoch 00009: val_accuracy improved from 0.65775 to 0.80388, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 10/50
# 160/160 [==============================] - 3s 18ms/step - loss: 0.8344 - accuracy: 0.7067 - val_loss: 0.5494 - val_accuracy: 0.8112
#
# Epoch 00010: val_accuracy improved from 0.80388 to 0.81124, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 11/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.6357 - accuracy: 0.7818 - val_loss: 0.2258 - val_accuracy: 0.9236
#
# Epoch 00011: val_accuracy improved from 0.81124 to 0.92364, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 12/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.5024 - accuracy: 0.8270 - val_loss: 0.2047 - val_accuracy: 0.9085
#
# Epoch 00012: val_accuracy did not improve from 0.92364
# Epoch 13/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.4119 - accuracy: 0.8618 - val_loss: 0.2242 - val_accuracy: 0.9221
#
# Epoch 00013: val_accuracy did not improve from 0.92364
# Epoch 14/50
# 160/160 [==============================] - 3s 18ms/step - loss: 0.3263 - accuracy: 0.8847 - val_loss: 0.2195 - val_accuracy: 0.9279
#
# Epoch 00014: val_accuracy improved from 0.92364 to 0.92791, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 15/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2864 - accuracy: 0.8982 - val_loss: 0.1405 - val_accuracy: 0.9481
#
# Epoch 00015: val_accuracy improved from 0.92791 to 0.94806, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 16/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2245 - accuracy: 0.9245 - val_loss: 0.1811 - val_accuracy: 0.9341
#
# Epoch 00016: val_accuracy did not improve from 0.94806
# Epoch 17/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1900 - accuracy: 0.9354 - val_loss: 0.1385 - val_accuracy: 0.9496
#
# Epoch 00017: val_accuracy improved from 0.94806 to 0.94961, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 18/50
# 160/160 [==============================] - 3s 18ms/step - loss: 0.1731 - accuracy: 0.9409 - val_loss: 0.0693 - val_accuracy: 0.9802
#
# Epoch 00018: val_accuracy improved from 0.94961 to 0.98023, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 19/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1488 - accuracy: 0.9497 - val_loss: 0.1697 - val_accuracy: 0.9461
#
# Epoch 00019: val_accuracy did not improve from 0.98023
# Epoch 20/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1461 - accuracy: 0.9502 - val_loss: 0.0468 - val_accuracy: 0.9841
#
# Epoch 00020: val_accuracy improved from 0.98023 to 0.98411, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 21/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1267 - accuracy: 0.9596 - val_loss: 0.0868 - val_accuracy: 0.9647
#
# Epoch 00021: val_accuracy did not improve from 0.98411
# Epoch 22/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.1198 - accuracy: 0.9600 - val_loss: 0.1058 - val_accuracy: 0.9655
#
# Epoch 00022: val_accuracy did not improve from 0.98411
# Epoch 23/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0915 - accuracy: 0.9701 - val_loss: 0.0321 - val_accuracy: 0.9915
#
# Epoch 00023: val_accuracy improved from 0.98411 to 0.99147, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 24/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0905 - accuracy: 0.9698 - val_loss: 0.0541 - val_accuracy: 0.9795
#
# Epoch 00024: val_accuracy did not improve from 0.99147
# Epoch 25/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0874 - accuracy: 0.9717 - val_loss: 0.0925 - val_accuracy: 0.9698
#
# Epoch 00025: val_accuracy did not improve from 0.99147
# Epoch 26/50
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0775 - accuracy: 0.9748 - val_loss: 0.0699 - val_accuracy: 0.9752
#
# Epoch 00026: val_accuracy did not improve from 0.99147
# Epoch 27/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0612 - accuracy: 0.9783 - val_loss: 0.0440 - val_accuracy: 0.9826
#
# Epoch 00027: val_accuracy did not improve from 0.99147
# Epoch 28/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0663 - accuracy: 0.9791 - val_loss: 0.1599 - val_accuracy: 0.9442
#
# Epoch 00028: val_accuracy did not improve from 0.99147
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 29/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0647 - accuracy: 0.9775 - val_loss: 0.0324 - val_accuracy: 0.9880
#
# Epoch 00029: val_accuracy did not improve from 0.99147
# Epoch 30/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0469 - accuracy: 0.9873 - val_loss: 0.0604 - val_accuracy: 0.9771
#
# Epoch 00030: val_accuracy did not improve from 0.99147
# Epoch 31/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0477 - accuracy: 0.9858 - val_loss: 0.0259 - val_accuracy: 0.9903
#
# Epoch 00031: val_accuracy did not improve from 0.99147
# Epoch 32/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0436 - accuracy: 0.9852 - val_loss: 0.0273 - val_accuracy: 0.9899
#
# Epoch 00032: val_accuracy did not improve from 0.99147
# Epoch 33/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0425 - accuracy: 0.9859 - val_loss: 0.0478 - val_accuracy: 0.9787
#
# Epoch 00033: val_accuracy did not improve from 0.99147
# Epoch 34/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0481 - accuracy: 0.9841 - val_loss: 0.0661 - val_accuracy: 0.9767
#
# Epoch 00034: val_accuracy did not improve from 0.99147
# Epoch 35/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0439 - accuracy: 0.9869 - val_loss: 0.0244 - val_accuracy: 0.9903
#
# Epoch 00035: val_accuracy did not improve from 0.99147
# Epoch 36/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0425 - accuracy: 0.9864 - val_loss: 0.0614 - val_accuracy: 0.9767
#
# Epoch 00036: val_accuracy did not improve from 0.99147
# Epoch 37/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0335 - accuracy: 0.9874 - val_loss: 0.0270 - val_accuracy: 0.9899
#
# Epoch 00037: val_accuracy did not improve from 0.99147
# Epoch 38/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0413 - accuracy: 0.9859 - val_loss: 0.0605 - val_accuracy: 0.9787
#
# Epoch 00038: val_accuracy did not improve from 0.99147
# Epoch 39/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0372 - accuracy: 0.9875 - val_loss: 0.0246 - val_accuracy: 0.9903
#
# Epoch 00039: val_accuracy did not improve from 0.99147
# Epoch 40/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0373 - accuracy: 0.9892 - val_loss: 0.0348 - val_accuracy: 0.9891
#
# Epoch 00040: val_accuracy did not improve from 0.99147
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 41/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0315 - accuracy: 0.9912 - val_loss: 0.0197 - val_accuracy: 0.9942
#
# Epoch 00041: val_accuracy improved from 0.99147 to 0.99419, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 42/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0314 - accuracy: 0.9907 - val_loss: 0.0181 - val_accuracy: 0.9946
#
# Epoch 00042: val_accuracy improved from 0.99419 to 0.99457, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 43/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0347 - accuracy: 0.9904 - val_loss: 0.0219 - val_accuracy: 0.9938
#
# Epoch 00043: val_accuracy did not improve from 0.99457
# Epoch 44/50
# 160/160 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.99 - 3s 17ms/step - loss: 0.0316 - accuracy: 0.9911 - val_loss: 0.0389 - val_accuracy: 0.9888
#
# Epoch 00044: val_accuracy did not improve from 0.99457
# Epoch 45/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0326 - accuracy: 0.9892 - val_loss: 0.0268 - val_accuracy: 0.9911
#
# Epoch 00045: val_accuracy did not improve from 0.99457
# Epoch 46/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0289 - accuracy: 0.9903 - val_loss: 0.0170 - val_accuracy: 0.9938
#
# Epoch 00046: val_accuracy did not improve from 0.99457
# Epoch 47/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0253 - accuracy: 0.9914 - val_loss: 0.0181 - val_accuracy: 0.9930
#
# Epoch 00047: val_accuracy did not improve from 0.99457
# Epoch 48/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.0175 - val_accuracy: 0.9953
#
# Epoch 00048: val_accuracy improved from 0.99457 to 0.99535, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 49/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0204 - accuracy: 0.9932 - val_loss: 0.0126 - val_accuracy: 0.9961
#
# Epoch 00049: val_accuracy improved from 0.99535 to 0.99612, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt
# Epoch 50/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0287 - accuracy: 0.9889 - val_loss: 0.0113 - val_accuracy: 0.9973
#
# Epoch 00050: val_accuracy improved from 0.99612 to 0.99729, saving model to d:/temp/DL04/DA_modelV2\cp.ckpt

# %%
show_history(historyV2)

modelV2.load_weights(file_pathV2)

evalV2 = modelV2.evaluate(testset, verbose=2)
valV2 = modelV2.evaluate(valset, verbose=2)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# 66/66 - 1s - loss: 0.0486 - accuracy: 0.9894
# 1/1 - 0s - loss: 0.0113 - accuracy: 0.9973

# %% [markdown]
# # Version III - Massive data augmentation

# %% [markdown]
# ### Data augmentation functions

# %%
import tensorflow_addons as tfa

def process_brightness(image, label):
    
    img = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.0, 1.0, 1.0, 0.1, 3.0),0,1)
    return img, label

def process_saturation(image, label):
    
    img = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.0, 1.0, 3.0, 1.0, 1.0),0,1)
    return img, label

def process_contrast(image, label):
    
    img = tf.clip_by_value(tf.image.random_contrast(image, lower=0.1, upper=3.0, seed=None), 0, 1)
    return img, label

def process_hue(image, label):
    
    img = tf.image.random_hue(image, max_delta=0.2, seed=None)
    return img, label

def process_rotate(image, label):
    
    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    return img, label

def process_shear(image, label):
    
    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    sx = tf.random.uniform(shape=(), minval=-0.1, maxval=0.1, dtype=tf.dtypes.float32)
    img = tfa.image.transform(img, [1, sx, -sx*32,   0,1,0,  0,0])
    return img, label

def process_translate(image, label):

    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    tx = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)
    ty = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)  
    img = tfa.image.translate(img, [tx,ty])
    return img, label

def process_crop(image, label):
    
    c = tf.random.uniform(shape=(), minval=24, maxval=32, dtype=tf.dtypes.float32)
    img = tf.image.random_crop(image, size=[c,c,3])
    img = tf.image.resize(img ,size= [32,32])
    return img, label

# %%
dataV3 = dataset
# color ops
dataV3 = dataV3.map(process_brightness)
dataV3 = dataV3.concatenate(dataset.map(process_contrast))
dataV3 = dataV3.concatenate(dataset.map(process_hue))
dataV3 = dataV3.concatenate(dataset.map(process_saturation))

#geometry ops
dataV3 = dataV3.concatenate(dataset.map(process_rotate))
dataV3 = dataV3.concatenate(dataset.map(process_shear))
dataV3 = dataV3.concatenate(dataset.map(process_translate))
dataV3 = dataV3.concatenate(dataset.map(process_crop))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)
#dataV3 = dataV3.repeat()

# %%
modelV3 = model_VI(8, 32, 3)

file_pathV3 = 'd:/temp/DL04/DA_modelV3/cp.ckpt'

callbacksV3 = prepare_callbacks(file_pathV3)

# historyV3 = modelV3.fit(dataV3, steps_per_epoch = 81600/BATCH_SIZE,
#           epochs=50, 
#           validation_data = valset, 
#           callbacks = callbacksV3)

historyV3 = modelV3.fit(dataV3,
          epochs=50, 
          validation_data = valset, 
          callbacks = callbacksV3)
# Out:
# Epoch 1/50
# 1275/1275 [==============================] - 27s 12ms/step - loss: 1.8454 - accuracy: 0.3348 - val_loss: 0.1948 - val_accuracy: 0.9450
#
# Epoch 00001: val_accuracy improved from -inf to 0.94496, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 2/50
# 1275/1275 [==============================] - 14s 11ms/step - loss: 0.4051 - accuracy: 0.8661 - val_loss: 0.0622 - val_accuracy: 0.9814
#
# Epoch 00002: val_accuracy improved from 0.94496 to 0.98140, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 3/50
# 1275/1275 [==============================] - 15s 11ms/step - loss: 0.1798 - accuracy: 0.9398 - val_loss: 0.0429 - val_accuracy: 0.9864
#
# Epoch 00003: val_accuracy improved from 0.98140 to 0.98643, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 4/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.1135 - accuracy: 0.9618 - val_loss: 0.0248 - val_accuracy: 0.9911
#
# Epoch 00004: val_accuracy improved from 0.98643 to 0.99109, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 5/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0786 - accuracy: 0.9740 - val_loss: 0.0164 - val_accuracy: 0.9922
#
# Epoch 00005: val_accuracy improved from 0.99109 to 0.99225, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 6/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0611 - accuracy: 0.9798 - val_loss: 0.0246 - val_accuracy: 0.9922
#
# Epoch 00006: val_accuracy did not improve from 0.99225
# Epoch 7/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0520 - accuracy: 0.9822 - val_loss: 0.0321 - val_accuracy: 0.9891
#
# Epoch 00007: val_accuracy did not improve from 0.99225
# Epoch 8/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0461 - accuracy: 0.9851 - val_loss: 0.0212 - val_accuracy: 0.9919
#
# Epoch 00008: val_accuracy did not improve from 0.99225
# Epoch 9/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0405 - accuracy: 0.9859 - val_loss: 0.0129 - val_accuracy: 0.9950
#
# Epoch 00009: val_accuracy improved from 0.99225 to 0.99496, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 10/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0319 - accuracy: 0.9887 - val_loss: 0.0131 - val_accuracy: 0.9953
#
# Epoch 00010: val_accuracy improved from 0.99496 to 0.99535, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 11/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0319 - accuracy: 0.9889 - val_loss: 0.0171 - val_accuracy: 0.9934
#
# Epoch 00011: val_accuracy did not improve from 0.99535
# Epoch 12/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0270 - accuracy: 0.9908 - val_loss: 0.0174 - val_accuracy: 0.9938
#
# Epoch 00012: val_accuracy did not improve from 0.99535
# Epoch 13/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0285 - accuracy: 0.9898 - val_loss: 0.0141 - val_accuracy: 0.9953
#
# Epoch 00013: val_accuracy did not improve from 0.99535
# Epoch 14/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0251 - accuracy: 0.9912 - val_loss: 0.0135 - val_accuracy: 0.9942
#
# Epoch 00014: val_accuracy did not improve from 0.99535
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 15/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0188 - accuracy: 0.9934 - val_loss: 0.0093 - val_accuracy: 0.9969
#
# Epoch 00015: val_accuracy improved from 0.99535 to 0.99690, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 16/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.0115 - val_accuracy: 0.9965
#
# Epoch 00016: val_accuracy did not improve from 0.99690
# Epoch 17/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.0147 - val_accuracy: 0.9961
#
# Epoch 00017: val_accuracy did not improve from 0.99690
# Epoch 18/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0147 - accuracy: 0.9946 - val_loss: 0.0134 - val_accuracy: 0.9950
#
# Epoch 00018: val_accuracy did not improve from 0.99690
# Epoch 19/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.0115 - val_accuracy: 0.9957
#
# Epoch 00019: val_accuracy did not improve from 0.99690
# Epoch 20/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.0067 - val_accuracy: 0.9977
#
# Epoch 00020: val_accuracy improved from 0.99690 to 0.99767, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 21/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0097 - val_accuracy: 0.9973
#
# Epoch 00021: val_accuracy did not improve from 0.99767
# Epoch 22/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0088 - val_accuracy: 0.9973
#
# Epoch 00022: val_accuracy did not improve from 0.99767
# Epoch 23/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0085 - val_accuracy: 0.9973
#
# Epoch 00023: val_accuracy did not improve from 0.99767
# Epoch 24/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0113 - val_accuracy: 0.9953
#
# Epoch 00024: val_accuracy did not improve from 0.99767
# Epoch 25/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0109 - accuracy: 0.9964 - val_loss: 0.0197 - val_accuracy: 0.9922
#
# Epoch 00025: val_accuracy did not improve from 0.99767
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 26/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0054 - val_accuracy: 0.9984
#
# Epoch 00026: val_accuracy improved from 0.99767 to 0.99845, saving model to d:/temp/DL04/DA_modelV3\cp.ckpt
# Epoch 27/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0072 - val_accuracy: 0.9977
#
# Epoch 00027: val_accuracy did not improve from 0.99845
# Epoch 28/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0094 - val_accuracy: 0.9961
#
# Epoch 00028: val_accuracy did not improve from 0.99845
# Epoch 29/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0106 - val_accuracy: 0.9969
#
# Epoch 00029: val_accuracy did not improve from 0.99845
# Epoch 30/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0126 - val_accuracy: 0.9961
#
# Epoch 00030: val_accuracy did not improve from 0.99845
# Epoch 31/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0099 - val_accuracy: 0.9973
#
# Epoch 00031: val_accuracy did not improve from 0.99845
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 32/50
# 1275/1275 [==============================] - 15s 11ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0097 - val_accuracy: 0.9969
#
# Epoch 00032: val_accuracy did not improve from 0.99845
# Epoch 33/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0084 - val_accuracy: 0.9977
#
# Epoch 00033: val_accuracy did not improve from 0.99845
# Epoch 34/50
# 1275/1275 [==============================] - 15s 11ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0080 - val_accuracy: 0.9977
#
# Epoch 00034: val_accuracy did not improve from 0.99845
# Epoch 35/50
# 1275/1275 [==============================] - 15s 12ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0088 - val_accuracy: 0.9981
#
# Epoch 00035: val_accuracy did not improve from 0.99845
# Epoch 36/50
# 1275/1275 [==============================] - 15s 11ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00036: val_accuracy did not improve from 0.99845
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 37/50
# 1275/1275 [==============================] - 15s 11ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0085 - val_accuracy: 0.9984
#
# Epoch 00037: val_accuracy did not improve from 0.99845
# Epoch 38/50
# 1275/1275 [==============================] - 15s 11ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0074 - val_accuracy: 0.9981
#
# Epoch 00038: val_accuracy did not improve from 0.99845
# Epoch 39/50
# 1275/1275 [==============================] - 15s 11ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0070 - val_accuracy: 0.9981
#
# Epoch 00039: val_accuracy did not improve from 0.99845
# Epoch 40/50
# 1275/1275 [==============================] - 15s 11ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0078 - val_accuracy: 0.9981
#
# Epoch 00040: val_accuracy did not improve from 0.99845
# Epoch 41/50
# 1275/1275 [==============================] - 15s 11ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.0076 - val_accuracy: 0.9984
#
# Epoch 00041: val_accuracy did not improve from 0.99845
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 00041: early stopping

# %%
show_history(historyV3)

modelV3.load_weights(file_pathV3)

evalV3 = modelV3.evaluate(testset, verbose=2)
valV3 = modelV3.evaluate(valset, verbose=2)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# 66/66 - 1s - loss: 0.0391 - accuracy: 0.9933
# 1/1 - 0s - loss: 0.0054 - accuracy: 0.9984

# %%
show_accuracies(['V1', 'V2', 'V3'], [evalV1[1], evalV2[1], evalV3[1]], [valV1[1], valV2[1], valV3[1]])

# %%
numpy_labels = []
numpy_images = []
pred = []

for images, labels in testset.take(-1):  # take all batches of dataset
    numpy_images.extend(images.numpy())
    numpy_labels.extend(labels.numpy())
    pred.extend(modelV3.predict(images.numpy()))


show_misclassified(pred, numpy_labels, numpy_images, int((4170 - 4170*.9933)/3 + 1))
# Out:
# 30

# %%
all_labels = [np.argmax(x) for x in numpy_labels]
all_preds = [np.argmax(x) for x in pred]
    
conf_mat = tf.math.confusion_matrix(all_labels, all_preds)

show_confusion_matrix(conf_mat.numpy(), 8)
